# %%
x = 10

if x == 10: # ':' then
        # pass -> pass 사용가능
    print("10입니다앙~!") # **** 들여쓰기 중요!!!!!!! ****
# Out:
# 10입니다앙~!

# %%
x = 10

if x == 10: # ':' then
    print("x에 들어있는 숫자는")
    print("10입니다아~!") # **** 들여쓰기 중요!!!!!!! ****
# Out:
# x에 들어있는 숫자는
# 10입니다아~!

# %%
x = 5

if x == 10: # ':' then
    print("x에 들어있는 숫자는")
print("10입니다아~!") # 이거는 if문에 들어가 있는게 아니라서 조건을 따지지 않고 프린트 단독으로 문장으로 나옴
# Out:
# 10입니다아~!

# %%
# 중첩 if 조건문 사용하기
# x = int(input("숫자를 입력하세요"))
# x = 10
# x = 15
x = 20

if x >= 10 :
    print("10 이상입니다")

    if x == 10 :
        print("10 입니다")
    
    if x == 20:
        print("20 입니다")
# Out:
# 10 이상입니다
# 20 입니다

# %%
x = int(input("숫자를 입력하세요"))

if x == 10:
    print("10입니다")

if x == 20:
    print("20입니다")
# Out:
# 20입니다

# %%
x = 5

if x !=10 :
    print("ok")
# Out:
# ok

# %%
price = int(input())
coupon = input()

if coupon == 'Cash3000':
    price -= 3000  # 3,000원 할인

if coupon == 'Cash5000':
    price -= 5000  # 5,000원 할인

print(price)
# Out:
# 47000
