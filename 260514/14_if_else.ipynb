# %%
# else 사용하기 

x = 5  # 이것은 조건문으로 사용할 수 없음

if x == 10: print("10입니다")
else : print("10이 아닙니다")
# Out:
# 10이 아닙니다

# %%
x = 5  

if x == 10: 
    print("10입니다")
else : 
    print("x에 들어있는 숫자는 ")
print("10이 아닙니다")  # if 밖의 print 문이라서 출력에 영향을 받지 않고 가능
# Out:
# x에 들어있는 숫자는
# 10이 아닙니다

# %%
# if 조건문의 동작 방식 알아보기

if True :
    print("참")

else : 
    print("거짓")

if False :
    print("참")

else : 
    print("거짓")
# Out:
# 참
# 거짓

# %%
if None : # 아무것도 없는?
    print("참")

else : 
    print("거짓")

bool(None)
# Out:
# 거짓
# False

# %%
if "hello": # 문자열이 있으면 참
    print("참")

else : 
    print("거짓")
# Out:
# 참

# %%
if "": # 문자열이 아무것도 없으면 거짓
    print("참")

else : 
    print("거짓")
# Out:
# 거짓

# %%
if []: # 비어있으면 다 거짓 
    print("참")

else : 
    print("거짓")
# Out:
# 거짓

# %%
x = 10
y = 20

if x == 10 and y == 20:
    print('참')
else :
    print('거짓')
# Out:
# 참

# %%
# 10이상이고 20미만인 숫자는 참

x = int(input("숫자를 입력하세요 : "))

# if x > 10 and x < 20 :
#     print("참")
# else :
#     print("거짓") 
    
if 10 <= x and 20 >= x :
    print("참")

else :
    print("거짓")
# Out:
# 거짓

# %%
if 10 <= x <= 20:
    print("참")
else : 
    print("거짓")
# Out:
# 거짓

# %%
written_test = 75
coding_test = True

if written_test > 80 and coding_test == True:
    print("합격")
else : 
    print("불합격")
# Out:
# 불합격

# %%
a,b,c,d = map(int, input().split())
a,b,c,d = score
average = score / 4 
if average > 80 :
    print("합격")

if avrage < 80 :
    print("불합격")


else :
    print("잘못된 점수")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 a,b,c,d = map(int, input().split())
# ----> 2 a,b,c,d = score
#       3 average = score / 4
#       4 if average > 80 :
#       5     print("합격")
#
# NameError: name 'score' is not defined
