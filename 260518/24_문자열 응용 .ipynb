# %%
# 문자열 바꾸기

"Hello, World!".replace("World", "Python") # .replace("원래 문자열", "바꾸는 문자열")

# %%
s = "Hello, world"
s= s.replace("world", "python")
# s에다가 재할당을 해야 문자열이 바뀜
print(s)

a = "Hello"
a = "hi" # Hello에서 hi 로 재할당 된 것임
print(a)

# %%
a = [1,2,3,4]

a.append(5)

print(a)

# %%
# 문자 바꾸기
# talbe = "".maketrans("aeiou", "12345")  
talbe = str.maketrans("aeiou", "12345") 
"apple".translate(table)

# a = 1  
# str(1)

# %%
# 문자열 분리하기 
"apple pear grape pineapple orange " .split()
# Out:
# ['apple', 'pear', 'grape', 'pineapple', 'orange']

# %%
# 문자열 분리하기 
"apple,pear,grape,pineapple,orange " .split() # 띄우지 않아서 공백 기준이 없기 때문에 하나로 통합되서 나타냄
# Out:
# ['apple,pear,grape,pineapple,orange']

# %%
# 구분자 문자열과 문자열 리스트 연결하기
" ".join(['apple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'apple pear grape pineapple orange'

# %%
"".join(['apple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'apple-pear-grape-pineapple-orange'

# %%
# 소문자를 대문자로 바꾸기

"python".upper() # upper : 대문자로 바꾸기
# Out:
# 'PYTHON'

# %%
# 대문자를 소문자로 바꾸기

'PYTHON'.lower() # lower : 소문자로 바꾸기
# Out:
# 'python'

# %%
# 왼쪽 공백 삭제하기 
"   python  ".lstrip() # lstrip : 왼쪽 공백 삭제하기
# Out:
# 'python  '

# %%
# 오른쪽 공백 삭제하기 
"   python  ".rstrip() # rstrip : 왼쪽 공백 삭제하기
# Out:
# '   python'

# %%
# 양쪾 공백 삭제하기
"   python  ".strip() # strip : 왼쪽 공백 삭제하기
# Out:
# 'python'

# %%
# 양쪽의 특정 문자 삭제하기 
",. python .," .strip(",.").strip()
# Out:
# 'python'

# %%
# 문자열을 왼쪽 정렬하기
"python".ljust(10) # just : 정렬하기
# Out:
# 'python    '

# %%
# 문자열을 오른쪽 정렬하기
"python".rjust(10)
# Out:
# '    python'

# %%
# 문자열을 가운데 정렬하기
"python".center(10) # 칸이 열개 있다고 생각하고 문자열 포함해서 양쪽 빈 공간을 나눔
# Out:
# '   python  '

# %%
# 문자열 왼쪽에 0 채우기
print("35".zfill(4))
print("3.5".zfill(6))
print("Hello".zfill(10))
# Out:
# 0035
# 0003.5
# 00000Hello

# %%
# 문자열 위치 찾기 

print("apple pineapple".find("pl")) #.find : 문자열 갯수를 찾아줌
# Out:
# 2

# %%
print("apple pineapple".find("xy")) # 찾는 값이 없으면 -1?
# Out:
# -1

# %%
print("apple pineapple".rfind("pl"))# 오른쪽에서 문자열 찾기
# Out:
# 12

# %%
# 문자열 위치 찾기 (index)
print("apple pineapple".index("pl")) # 뒤에 pl찾지 않고 앞에서 찾고 종료함
# Out:
# 2

# %%
# 문자열 개수 세기 (count)
print("apple pineapple".count("pl"))
# Out:
# 2

# %%
# 문자열 서식 지정자와 포매팅 사용하기 

# 형식 : "%s" % "문자열" 혹은 변수

"I am %s" % "James"
# Out:
# 'I am James'

# %%
name = "Maria"
"I am %s" % name
# Out:
# 'I am Maria'

# %%
# 서식 지정자로 숫자 넣기 
# 형식 : "%d" % 숫자

"I am %d years old " % 20
# Out:
# 'I am 20 years old '

# %%
# 서식 지정자로 소수점 표현하기
"%f" % 2.3
# Out:
# '2.300000'

# %%
"%.2f" % 2.3 # 소수점 2자리까지 표현
# Out:
# '2.30'

# %%
"%.3f" % 2.3 # 소수점 3자리까지 표현
# Out:
# '2.300'

# %%
# 서식 지정자로 문자열 정렬

print("%10s" % "python") # 문자열 10자리에 공백을 넣고 python 넣기
print("%-10s" % "python")
# Out:
#     python
# python

# %%
# 서식 지정자로 문자열 값에 여러 개 넣기 

"Today is %d %s" % (3, "April")  # %d : 숫자 , %s : 문자열
# Out:
# 'Today is 3 April'

# %%
# format 매서드 사용하기 
print("Hello, {0}". format("world"))
print("Hello, {0},{1}". format(100,"t")) 
# 형식 :  문자열, {0},{1}.. (index 번호) . format(변환값, 변환값1...)
# Out:
# Hello, world
# Hello, 100,t

# %%
"Hello {0} {2} {1}".format("python", "script", 3.6)
# Out:
# 'Hello python 3.6 script'

# %%
"Hello {} {} {}".format("python", "script", 3.6)
# Out:
# 'Hello python script 3.6'

# %%
"Hello {language} {version}".format(language="Python", version =  3.6)
# Out:
# 'Hello Python 3.6'

# %%
language = "Python"
version = 3.6 
f"Hello, {language} {version}" # 이게 제일 편리함
# `Hello, {language} {version}'  ' ` ' : Back tic ? 느낌표 옆 기호 (Java에서 많이 쓰임)
# Out:
# 'Hello, Python 3.6'

# %%
# format 매서드로 문자열 정리하기 
print("{0:<10}".format("python")) # < 왼쪽으로 정렬하기
print("{0:>10}".format("python")) # > 오른쪽으로 정렬하기
# Out:
# python
#     python

# %%
# 숫자 개수 맞추기 

" %03d" % 1
# Out:
# ' 001'

# %%
"{0:03d} ".format(35)
# Out:
# '035 '

# %%
print("%f" % 3.6 )
print("%8.2f" % 3.6 )
print("%08.2f" % 3.6 )
# Out:
# 3.600000
#     3.60
# 00003.60

# %%
a=(12345.98765)

print(f"{a:12,.2f}")
# Out:
#    12,345.99

# %%
path = 'C:\\Users\\dojang\\AppData\\Local\\Programs\\Python\\Python36-32\\python.exe'
x = path.split('\\')
print(x)
print(x[-1])
 
print(filename)
# Out:
# ['C:', 'Users', 'dojang', 'AppData', 'Local', 'Programs', 'Python', 'Python36-32', 'python.exe']
# python.exe
# python.exe

# %%
a = " ., python ,.". strip(",.") # 이거는 공백을 포함 안한 strip이기 때문에 삭제 하지 못함
print(a)
# Out:
#  ., python
