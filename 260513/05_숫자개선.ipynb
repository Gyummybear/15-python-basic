# %%
# 사칙연산 

print(1 + 1)
1-1 # 쉘 마지막은 출력이 된다. 이거는 두 번째 줄이라서 출력이 안됨
print(2 * 2)
print(4 / 2) # 실수 나누기

# %%
# 나눗셈 후 소수점 이하를 버리는 // 연산자 (몫)
5 // 2

# %%
# % 연산자 (나머지를 구하는 연산자)

5 % 2 # 나머지가 1이 나옴 5 나누기 2 나머지는 1

# %%
# ** (거듭 제곱 연산자)
2**10

# 제곱근
4 ** 0.5 # 제곱근 구하기

# %%
#  값을 정수로 만들기 
a = int(3.3) # 실수를 정수로 만들어주는 int() 함수
print (a)
print( 4 / 2 ) # 실수 나누기
# Out:
# 3
# 2.0

# %%
# 객체의 자료형 알아내기(type)
type(10)
# Out:
# int

# %%
# 2진수
a = 0b110 # 2진수 : 0과 1로 이루어진 수 체계
print(a)
(1 * 2**2) + (1 * 2**1) + 0 * (2**0)

b = 0b111111 # (1* 2**5) + (1* 2**4) + (1* 2**3) + (1* 2**2) + (1* 2**1) + (1* 2**0)
print(b)
# Out:
# 6
# 63

# %%
# 8진수
0o110 
(1 * 8**2)+ (1 * 8**1) + (0 * 8**0)
# Out:
# 72

# %%
# 16진수 
0xAF
print(0xAF)
(10 * 16**1) + (15 * 16**0)

# %%
# 실수 계산하기 
3.5 + 2.1
# Out:
# 5.6

# %%
4.2 + 5

# %%
# 값을 실수로 만들기 (float)

float(5) # 정수를 실수로 만들기
float()
float("5.3") # -> 문자열
# float("hi") # -> 문자열이지만 숫자열이 아니기 때문에 에러가 발생함
# Out:
# 5.3

# %%
float(4)
# Out:
# 4.0

# %%
# 괄호 사용하기 ()
print(2 + 2 * 2)
print((2 + 2) * 2)
